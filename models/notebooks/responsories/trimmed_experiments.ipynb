# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Trimmed experiments - Responsories

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:4922].tolist(), y[4922:].tolist()
final_segmentation = []
f = open("responsories_segmentation.txt", "r")
for chant in f:
    chant = chant.replace('\n', '')
    final_segmentation.append(chant.split(' '))
train_segmentation, test_segmentation = final_segmentation[:4922], final_segmentation[4922:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 15)
# Out:
# INFO:root:Number of chants: 7031
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 94.17%, Left f1: 94.17%, Right accuracy: 94.17%, Right f1: 94.17%, Both accuracy: 94.17%, Both f1: 94.17%, Rand accuracy: 94.17%, Rand f1: 94.17%
# 		 1 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 94.12%, Left f1: 94.13%, Right accuracy: 94.17%, Right f1: 94.17%, Both accuracy: 94.17%, Both f1: 94.17%, Rand accuracy: 94.22%, Rand f1: 94.22%
# 		 6 train chants are too short to not to be trimmed
# 		 2 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 94.02%, Left f1: 94.03%, Right accuracy: 94.11%, Right f1: 94.12%, Both accuracy: 94.11%, Both f1: 94.12%, Rand accuracy: 94.07%, Rand f1: 94.07%
# ...
