# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# Requirement already satisfied: levenshtein in /usr/local/lib/python3.10/dist-packages (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from levenshtein) (3.1.1)

# %% [markdown]
# ## Trimmed experiments - Antiphones without differencies

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:9486].tolist(), y[9486:].tolist()
final_segmentation = []
f = open("antiphonsno4_segmentation.txt", "r")
for chant in f:
    chant = chant.replace('\n', '')
    final_segmentation.append(chant.split(' '))
train_segmentation, test_segmentation = final_segmentation[:9486], final_segmentation[9486:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 6)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:root:Number of chants: 13551
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 93.97%, Left f1: 93.96%, Right accuracy: 93.97%, Right f1: 93.96%, Both accuracy: 93.97%, Both f1: 93.96%, Rand accuracy: 93.97%, Rand f1: 93.96%
# 		 20 train chants are too short to not to be trimmed
# 		 2 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 93.50%, Left f1: 93.48%, Right accuracy: 93.33%, Right f1: 93.31%, Both accuracy: 93.11%, Both f1: 93.08%, Rand accuracy: 93.31%, Rand f1: 93.29%
# 		 162 train chants are too short to not to be trimmed
# 		 46 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 92.06%, Left f1: 92.00%, Right accuracy: 92.81%, Right f1: 92.78%, Both accuracy: 91.84%, Both f1: 91.81%, Rand accuracy: 92.29%, Rand f1: 92.25%
# 		 820 train chants are too short to not to be trimmed
# 		 248 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 91.43%, Left f1: 91.33%, Right accuracy: 91.96%, Right f1: 91.90%, Both accuracy: 88.81%, Both f1: 88.74%, Rand accuracy: 89.73%, Rand f1: 89.69%
# 		 1933 train chants are too short to not to be trimmed
# 		 632 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 89.95%, Left f1: 89.85%, Right accuracy: 90.50%, Right f1: 90.40%, Both accuracy: 85.76%, Both f1: 85.61%, Rand accuracy: 86.95%, Rand f1: 86.85%
# 		 3076 train chants are too short to not to be trimmed
# 		 1072 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 88.84%, Left f1: 88.62%, Right accuracy: 89.94%, Right f1: 89.85%, Both accuracy: 84.16%, Both f1: 83.99%, Rand accuracy: 85.87%, Rand f1: 85.69%
# 		 4102 train chants are too short to not to be trimmed
# 		 1485 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 88.91%, Left f1: 88.73%, Right accuracy: 89.50%, Right f1: 89.37%, Both accuracy: 83.45%, Both f1: 83.20%, Rand accuracy: 84.26%, Rand f1: 84.04%
