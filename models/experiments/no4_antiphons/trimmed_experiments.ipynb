# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting levenshtein
#   Downloading Levenshtein-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 7.0 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 51.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.21.0 rapidfuzz-3.0.0

# %% [markdown]
# ## Trimmed experiments - Antiphones without differencies

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:9486].tolist(), y[9486:].tolist()
word_segmentations = load_word_segmentations()
train_segmentation, test_segmentation = word_segmentations[:9486], word_segmentations[9486:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 6)
# Out:
# INFO:root:Number of chants: 13551
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 90.63%, Left f1: 90.56%, Right accuracy: 90.63%, Right f1: 90.56%, Both accuracy: 90.63%, Both f1: 90.56%, Rand accuracy: 90.63%, Rand f1: 90.56%
# 		 15 train chants are too short to not to be trimmed
# 		 5 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 87.76%, Left f1: 87.64%, Right accuracy: 87.19%, Right f1: 87.07%, Both accuracy: 85.37%, Both f1: 85.20%, Rand accuracy: 87.96%, Rand f1: 87.83%
# 		 43 train chants are too short to not to be trimmed
# 		 19 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 84.35%, Left f1: 84.19%, Right accuracy: 86.97%, Right f1: 86.87%, Both accuracy: 82.33%, Both f1: 82.12%, Rand accuracy: 83.27%, Rand f1: 83.08%
# 		 345 train chants are too short to not to be trimmed
# 		 176 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 81.77%, Left f1: 81.52%, Right accuracy: 85.60%, Right f1: 85.39%, Both accuracy: 79.20%, Both f1: 78.93%, Rand accuracy: 78.94%, Rand f1: 78.61%
# 		 1200 train chants are too short to not to be trimmed
# 		 543 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 78.85%, Left f1: 78.48%, Right accuracy: 83.84%, Right f1: 83.57%, Both accuracy: 75.44%, Both f1: 75.01%, Rand accuracy: 73.96%, Rand f1: 73.27%
# 		 2624 train chants are too short to not to be trimmed
# 		 1162 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 78.02%, Left f1: 77.39%, Right accuracy: 82.81%, Right f1: 82.45%, Both accuracy: 72.30%, Both f1: 71.66%, Rand accuracy: 70.07%, Rand f1: 69.23%
# 		 4343 train chants are too short to not to be trimmed
# 		 1870 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 78.13%, Left f1: 77.33%, Right accuracy: 80.82%, Right f1: 80.28%, Both accuracy: 70.98%, Both f1: 70.23%, Rand accuracy: 67.33%, Rand f1: 66.07%
