# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting levenshtein
#   Downloading Levenshtein-0.20.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 4.3 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.15.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 45.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.20.9 rapidfuzz-2.15.1

# %% [markdown]
# ## Trimmed experiments - Antiphones without differencies

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:9706].tolist(), y[9706:].tolist()
word_segmentations = load_word_segmentations()
train_segmentation, test_segmentation = word_segmentations[:9706], word_segmentations[9706:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 6)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:root:Number of chants: 13551
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 90.46%, Left f1: 90.35%, Right accuracy: 90.46%, Right f1: 90.35%, Both accuracy: 90.46%, Both f1: 90.35%, Rand accuracy: 90.46%, Rand f1: 90.35%
# 		 15 train chants are too short to not to be trimmed
# 		 5 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 87.50%, Left f1: 87.40%, Right accuracy: 87.27%, Right f1: 87.14%, Both accuracy: 85.21%, Both f1: 85.06%, Rand accuracy: 88.15%, Rand f1: 88.03%
# 		 43 train chants are too short to not to be trimmed
# 		 19 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 83.98%, Left f1: 83.85%, Right accuracy: 87.43%, Right f1: 87.34%, Both accuracy: 82.49%, Both f1: 82.27%, Rand accuracy: 83.27%, Rand f1: 83.08%
# 		 365 train chants are too short to not to be trimmed
# 		 156 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 81.70%, Left f1: 81.49%, Right accuracy: 85.61%, Right f1: 85.44%, Both accuracy: 79.62%, Both f1: 79.32%, Rand accuracy: 79.18%, Rand f1: 78.84%
# 		 1256 train chants are too short to not to be trimmed
# 		 487 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 77.75%, Left f1: 77.26%, Right accuracy: 83.80%, Right f1: 83.52%, Both accuracy: 74.69%, Both f1: 74.28%, Rand accuracy: 72.22%, Rand f1: 71.64%
# 		 2729 train chants are too short to not to be trimmed
# 		 1057 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 77.37%, Left f1: 76.68%, Right accuracy: 81.71%, Right f1: 81.28%, Both accuracy: 72.24%, Both f1: 71.60%, Rand accuracy: 67.50%, Rand f1: 66.76%
# 		 4472 train chants are too short to not to be trimmed
# 		 1741 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 77.09%, Left f1: 76.34%, Right accuracy: 80.61%, Right f1: 79.99%, Both accuracy: 70.91%, Both f1: 70.13%, Rand accuracy: 67.78%, Rand f1: 66.75%
