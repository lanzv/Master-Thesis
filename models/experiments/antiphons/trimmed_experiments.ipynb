# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting levenshtein
#   Downloading Levenshtein-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 5.4 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 47.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.21.0 rapidfuzz-3.0.0

# %% [markdown]
# ## Trimmed experiments - Antiphones

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:9706].tolist(), y[9706:].tolist()
word_segmentations = load_word_segmentations()
train_segmentation, test_segmentation = word_segmentations[:9706], word_segmentations[9706:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 6)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:root:Number of chants: 13865
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 95.34%, Left f1: 95.30%, Right accuracy: 95.34%, Right f1: 95.30%, Both accuracy: 95.34%, Both f1: 95.30%, Rand accuracy: 95.34%, Rand f1: 95.30%
# 		 15 train chants are too short to not to be trimmed
# 		 3 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 94.03%, Left f1: 94.00%, Right accuracy: 88.45%, Right f1: 88.32%, Both accuracy: 88.91%, Both f1: 88.82%, Rand accuracy: 92.88%, Rand f1: 92.83%
# 		 48 train chants are too short to not to be trimmed
# 		 10 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 93.03%, Left f1: 92.98%, Right accuracy: 87.49%, Right f1: 87.31%, Both accuracy: 84.19%, Both f1: 84.01%, Rand accuracy: 90.79%, Rand f1: 90.71%
# 		 150 train chants are too short to not to be trimmed
# 		 45 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 92.17%, Left f1: 92.11%, Right accuracy: 86.12%, Right f1: 85.97%, Both accuracy: 78.10%, Both f1: 77.81%, Rand accuracy: 86.12%, Rand f1: 85.97%
# 		 770 train chants are too short to not to be trimmed
# 		 322 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 91.11%, Left f1: 91.02%, Right accuracy: 85.54%, Right f1: 85.37%, Both accuracy: 74.62%, Both f1: 74.22%, Rand accuracy: 80.35%, Rand f1: 79.95%
# 		 1923 train chants are too short to not to be trimmed
# 		 842 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 90.56%, Left f1: 90.44%, Right accuracy: 82.42%, Right f1: 81.96%, Both accuracy: 70.55%, Both f1: 69.84%, Rand accuracy: 76.03%, Rand f1: 75.35%
# 		 3651 train chants are too short to not to be trimmed
# 		 1600 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 91.05%, Left f1: 90.93%, Right accuracy: 82.22%, Right f1: 81.79%, Both accuracy: 68.62%, Both f1: 67.89%, Rand accuracy: 71.86%, Rand f1: 71.11%
