# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# Collecting levenshtein
#   Downloading Levenshtein-0.21.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 5.0 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from levenshtein)
#   Downloading rapidfuzz-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 42.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.21.1 rapidfuzz-3.1.1

# %% [markdown]
# ## Trimmed experiments - Antiphones

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:9706].tolist(), y[9706:].tolist()
final_segmentation = []
f = open("antiphons_segmentation.txt", "r")
for chant in f:
    chant = chant.replace('\n', '')
    final_segmentation.append(chant.split(' '))
train_segmentation, test_segmentation = final_segmentation[:9706], final_segmentation[9706:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 6)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:root:Number of chants: 13865
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 96.10%, Left f1: 96.10%, Right accuracy: 96.10%, Right f1: 96.10%, Both accuracy: 96.10%, Both f1: 96.10%, Rand accuracy: 96.10%, Rand f1: 96.10%
# 		 16 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 95.94%, Left f1: 95.93%, Right accuracy: 95.79%, Right f1: 95.79%, Both accuracy: 95.72%, Both f1: 95.72%, Rand accuracy: 95.91%, Rand f1: 95.91%
# 		 81 train chants are too short to not to be trimmed
# 		 15 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 95.83%, Left f1: 95.82%, Right accuracy: 95.54%, Right f1: 95.53%, Both accuracy: 94.57%, Both f1: 94.56%, Rand accuracy: 95.15%, Rand f1: 95.14%
# 		 448 train chants are too short to not to be trimmed
# 		 113 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 95.40%, Left f1: 95.40%, Right accuracy: 94.44%, Right f1: 94.42%, Both accuracy: 91.97%, Both f1: 91.94%, Rand accuracy: 93.62%, Rand f1: 93.60%
# 		 1246 train chants are too short to not to be trimmed
# 		 394 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 94.74%, Left f1: 94.73%, Right accuracy: 93.57%, Right f1: 93.54%, Both accuracy: 90.17%, Both f1: 90.12%, Rand accuracy: 91.74%, Rand f1: 91.69%
# 		 2499 train chants are too short to not to be trimmed
# 		 831 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 94.35%, Left f1: 94.33%, Right accuracy: 92.76%, Right f1: 92.73%, Both accuracy: 87.89%, Both f1: 87.81%, Rand accuracy: 89.36%, Rand f1: 89.31%
# 		 3603 train chants are too short to not to be trimmed
# 		 1261 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 94.13%, Left f1: 94.11%, Right accuracy: 91.99%, Right f1: 91.96%, Both accuracy: 87.20%, Both f1: 87.10%, Rand accuracy: 88.85%, Rand f1: 88.79%
