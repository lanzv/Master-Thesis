# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
# !pip install levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting levenshtein
#   Downloading Levenshtein-0.20.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 7.6 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.15.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 60.2 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein
# Successfully installed levenshtein-0.20.9 rapidfuzz-2.15.0

# %%
from src.utils.loader import prepare_dataset, load_word_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:4922].tolist(), y[4922:].tolist()
word_segmentations = load_word_segmentations()
train_segmentation, test_segmentation = word_segmentations[:4922], word_segmentations[4922:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 6)
# Out:
# INFO:root:Number of chants: 7031
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 91.56%, Left f1: 91.53%, Right accuracy: 91.56%, Right f1: 91.53%, Both accuracy: 91.56%, Both f1: 91.53%
# 		 1 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 90.80%, Left f1: 90.76%, Right accuracy: 89.81%, Right f1: 89.75%, Both accuracy: 89.81%, Both f1: 89.75%
# 		 14 train chants are too short to not to be trimmed
# 		 7 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 89.20%, Left f1: 89.14%, Right accuracy: 89.01%, Right f1: 88.97%, Both accuracy: 88.58%, Both f1: 88.50%
# 		 34 train chants are too short to not to be trimmed
# 		 15 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 87.82%, Left f1: 87.77%, Right accuracy: 87.30%, Right f1: 87.25%, Both accuracy: 86.39%, Both f1: 86.32%
# 		 91 train chants are too short to not to be trimmed
# 		 42 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 87.08%, Left f1: 87.01%, Right accuracy: 85.34%, Right f1: 85.33%, Both accuracy: 85.00%, Both f1: 84.97%
# 		 211 train chants are too short to not to be trimmed
# 		 108 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 85.11%, Left f1: 85.03%, Right accuracy: 85.91%, Right f1: 85.89%, Both accuracy: 82.66%, Both f1: 82.51%
# 		 519 train chants are too short to not to be trimmed
# 		 227 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 82.20%, Left f1: 82.09%, Right accuracy: 83.53%, Right f1: 83.60%, Both accuracy: 81.14%, Both f1: 81.03%

# %%
from src.utils.loader import prepare_dataset, load_syllable_segmentations
from src.eval.pipelines import evaluation_trimmed_chants


# Get Data
_, y = prepare_dataset()
y_train, y_test = y[:4922].tolist(), y[4922:].tolist()
word_segmentations = load_syllable_segmentations()
train_segmentation, test_segmentation = word_segmentations[:4922], word_segmentations[4922:]
# Evaluate model
bacor_model = evaluation_trimmed_chants(
    train_segmentation, y_train, test_segmentation, y_test, 15)
# Out:
# INFO:root:Number of chants: 7031
# ------------------- Trimmed Evalution Pipeline -----------------
#
#
# 		 0 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 0 trimmed segments, Left accuracy: 93.69%, Left f1: 93.68%, Right accuracy: 93.69%, Right f1: 93.68%, Both accuracy: 93.69%, Both f1: 93.68%
# 		 1 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 2 trimmed segments, Left accuracy: 93.31%, Left f1: 93.31%, Right accuracy: 92.60%, Right f1: 92.59%, Both accuracy: 93.41%, Both f1: 93.40%
# 		 1 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 4 trimmed segments, Left accuracy: 93.46%, Left f1: 93.45%, Right accuracy: 92.46%, Right f1: 92.46%, Both accuracy: 92.41%, Both f1: 92.41%
# 		 2 train chants are too short to not to be trimmed
# 		 0 test chants are too short to not to be trimmed
# 		 6 trimmed segments, Left accuracy: 93.46%, Left f1: 93.44%, Right accuracy: 92.41%, Right f1: 92.40%, Both accuracy: 91.99%, Both f1: 91.97%
# 		 8 train chants are too short to not to be trimmed
# 		 2 test chants are too short to not to be trimmed
# 		 8 trimmed segments, Left accuracy: 93.26%, Left f1: 93.26%, Right accuracy: 92.07%, Right f1: 92.06%, Both accuracy: 91.79%, Both f1: 91.77%
# 		 20 train chants are too short to not to be trimmed
# 		 7 test chants are too short to not to be trimmed
# 		 10 trimmed segments, Left accuracy: 93.01%, Left f1: 93.00%, Right accuracy: 92.15%, Right f1: 92.14%, Both accuracy: 91.44%, Both f1: 91.40%
# 		 26 train chants are too short to not to be trimmed
# 		 12 test chants are too short to not to be trimmed
# 		 12 trimmed segments, Left accuracy: 92.27%, Left f1: 92.28%, Right accuracy: 91.89%, Right f1: 91.88%, Both accuracy: 91.13%, Both f1: 91.11%
# 		 33 train chants are too short to not to be trimmed
# 		 15 test chants are too short to not to be trimmed
# 		 14 trimmed segments, Left accuracy: 92.50%, Left f1: 92.49%, Right accuracy: 91.50%, Right f1: 91.46%, Both accuracy: 91.12%, Both f1: 91.09%
# 		 42 train chants are too short to not to be trimmed
# 		 18 test chants are too short to not to be trimmed
# 		 16 trimmed segments, Left accuracy: 92.25%, Left f1: 92.21%, Right accuracy: 91.82%, Right f1: 91.77%, Both accuracy: 90.87%, Both f1: 90.84%
# 		 50 train chants are too short to not to be trimmed
# 		 19 test chants are too short to not to be trimmed
# 		 18 trimmed segments, Left accuracy: 92.30%, Left f1: 92.27%, Right accuracy: 90.57%, Right f1: 90.52%, Both accuracy: 89.33%, Both f1: 89.30%
# 		 77 train chants are too short to not to be trimmed
# 		 31 test chants are too short to not to be trimmed
# 		 20 trimmed segments, Left accuracy: 91.39%, Left f1: 91.34%, Right accuracy: 89.22%, Right f1: 89.17%, Both accuracy: 89.70%, Both f1: 89.62%
# 		 120 train chants are too short to not to be trimmed
# 		 55 test chants are too short to not to be trimmed
# 		 22 trimmed segments, Left accuracy: 90.75%, Left f1: 90.72%, Right accuracy: 89.78%, Right f1: 89.70%, Both accuracy: 88.41%, Both f1: 88.36%
# 		 178 train chants are too short to not to be trimmed
# 		 80 test chants are too short to not to be trimmed
# 		 24 trimmed segments, Left accuracy: 89.60%, Left f1: 89.53%, Right accuracy: 88.86%, Right f1: 88.80%, Both accuracy: 87.04%, Both f1: 86.97%
# 		 275 train chants are too short to not to be trimmed
# 		 121 test chants are too short to not to be trimmed
# 		 26 trimmed segments, Left accuracy: 89.49%, Left f1: 89.44%, Right accuracy: 88.68%, Right f1: 88.62%, Both accuracy: 86.57%, Both f1: 86.49%
# 		 407 train chants are too short to not to be trimmed
# 		 181 test chants are too short to not to be trimmed
# 		 28 trimmed segments, Left accuracy: 88.49%, Left f1: 88.39%, Right accuracy: 87.55%, Right f1: 87.48%, Both accuracy: 85.17%, Both f1: 85.08%
# 		 539 train chants are too short to not to be trimmed
# 		 238 test chants are too short to not to be trimmed
# 		 30 trimmed segments, Left accuracy: 86.64%, Left f1: 86.49%, Right accuracy: 86.80%, Right f1: 86.70%, Both accuracy: 85.20%, Both f1: 85.11%
